# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
sns.set_palette('husl')
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn import metrics
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.linear_model import LogisticRegression 
from sklearn.model_selection import train_test_split 

data= pd.read_csv('/content/sample_data/fortune_global_500_from_2019-2021.csv')

# %%
data.head()
# Out:
#    year  rank  ... jobgrowth                                          permalink
# 0  2019   1.0  ...        no        https://fortune.com/global500/2019/walmart/
# 1  2019   2.0  ...        no  https://fortune.com/global500/2019/sinopec-group/
# 2  2019   3.0  ...        no  https://fortune.com/global500/2019/royal-dutch...
# 3  2019   4.0  ...        no  https://fortune.com/global500/2019/china-natio...
# 4  2019   5.0  ...       yes     https://fortune.com/global500/2019/state-grid/
#
# [5 rows x 18 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        1500 non-null   int64
#  1   rank        1500 non-null   float64
#  2   name        1500 non-null   object
#  3   sector      1500 non-null   object
#  4   industry    1500 non-null   object
#  5   revenues    1500 non-null   float64
#  6   revchange   1490 non-null   float64
#  7   profits     1499 non-null   float64
#  8   prftchange  1380 non-null   float64
#  9   assets      1500 non-null   float64
#  10  employees   1500 non-null   int64
#  11  hqcity      1494 non-null   object
#  12  hqstate     364 non-null    object
#  13  newcomer    1500 non-null   object
#  14  profitable  1500 non-null   object
#  15  ceowoman    1500 non-null   object
#  16  jobgrowth   1500 non-null   object
#  17  permalink   1500 non-null   object
# dtypes: float64(6), int64(2), object(10)
# ...

# %%
data.describe()
# Out:
#               year         rank  ...        assets     employees
# count  1500.000000  1500.000000  ...  1.500000e+03  1.500000e+03
# mean   2020.000000   250.258667  ...  2.871457e+05  1.392439e+05
# std       0.816769   144.132031  ...  5.744032e+05  1.696815e+05
# min    2019.000000     1.000000  ...  3.209400e+03  3.770000e+02
# 25%    2019.000000   125.750000  ...  4.428657e+04  4.765175e+04
# 50%    2020.000000   250.500000  ...  8.723500e+04  9.546650e+04
# 75%    2021.000000   375.000000  ...  2.340597e+05  1.711608e+05
# max    2021.000000   500.000000  ...  5.110354e+06  2.300000e+06
#
# [8 rows x 8 columns]

# %%
tmp = data.drop('rank', axis=1)
g = sns.pairplot(tmp, hue='name', markers='+')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-b18ad5717cea> in <module>()
#       1 tmp = data.drop('rank', axis=1)
# ----> 2 g = sns.pairplot(tmp, hue='name', markers='+')
#       3 plt.show()
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2138     if kind == "scatter":
#    2139         from .relational import scatterplot  # Avoid circular import
# -> 2140         plotter(scatterplot, **plot_kws)
# ...

# %%
data['name'].value_counts()
# Out:
# Shandong Energy Group       4
# Gree Electric Appliances    3
# Wistron                     3
# HBIS Group                  3
# Telefónica                  3
#                            ..
# China Resources Land        1
# Oil &#038; Natural Gas      1
# Yankuang Group              1
# Micron Technology           1
# Sunac China Holdings        1
# Name: name, Length: 607, dtype: int64

# %%
g = sns.violinplot(y='name', x='revenues', data=data, inner='quartile')
plt.show()
g = sns.violinplot(y='name', x='revchange', data=data, inner='quartile')
plt.show()
g = sns.violinplot(y='name', x='profits', data=data, inner='quartile')
plt.show()
g = sns.violinplot(y='name', x='prftchange', data=data, inner='quartile')
plt.show()

# %%
X = data.drop(['rank', 'name'], axis=1)
y = data['name']
# print(X.head())
print(X.shape)
# print(y.head())
print(y.shape)
# Out:
# (1500, 16)
# (1500,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=5)
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (900, 16)
# (900,)
# (600, 16)
# (600,)
